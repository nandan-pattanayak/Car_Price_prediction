# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read dataset
train_data=pd.read_csv("train-data.csv")

# %%
#read dataset
test_data=pd.read_csv("test-data.csv")

# %%
#combine train and test dataset
final_dataset=train_data.append(test_data,sort=False)

# %%
#drop a unnessasory column
final_dataset=final_dataset.drop(['Unnamed: 0'],axis=1)

# %%
final_dataset.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# dtype: object

# %%
#dataset contain null values
sns.heatmap(final_dataset.isnull())

# %%
#drop the NewPrice columns   
final_dataset=final_dataset.drop(['New_Price'],axis=1)

# %%
sns.heatmap(final_dataset.isnull(),yticklabels=False,cmap="viridis")

# %%
final_dataset.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# Price                1234
# dtype: int64

# %%
final_dataset.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %%
final_dataset.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
final_dataset['Mileage']=final_dataset['Mileage'].str.split(" ").str[0]

# %%
final_dataset['Mileage']=final_dataset['Mileage'].astype(float)

# %%
np.mean(final_dataset['Mileage'])
# Out:
# 18.14158047165911

# %%
final_dataset["Mileage"]=final_dataset['Mileage'].fillna(18.1)

# %%
final_dataset.head(40)
# Out:
#                                                 Name    Location  Year  \
# 0                             Maruti Wagon R LXI CNG      Mumbai  2010
# 1                   Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                       Honda Jazz V     Chennai  2011
# 3                                  Maruti Ertiga VDI     Chennai  2012
# 4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                    Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                             Nissan Micra Diesel XV      Jaipur  2013
# 7                  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                     Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                  Maruti Ciaz Zeta       Kochi  2018
# 11                       Honda City 1.5 V AT Sunroof     Kolkata  2012
# ...

# %%
final_dataset['Engine']=final_dataset["Engine"].str.split(" ").str[0]
final_dataset['Engine']=final_dataset["Engine"].astype(float)

# %%
engine_mean=final_dataset['Engine'].mean()
engine_mean
final_dataset['Engine']=final_dataset['Engine'].fillna(1616)

# %%
sns.heatmap(final_dataset.isnull())

# %%
final_dataset.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %%
final_dataset=final_dataset.drop(['Power'],axis=1)

# %%
final_dataset.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine  Seats  Price
# 0       CNG       Manual      First    26.60   998.0    5.0   1.75
# 1    Diesel       Manual      First    19.67  1582.0    5.0  12.50
# 2    Petrol       Manual      First    18.20  1199.0    5.0   4.50
# 3    Diesel       Manual      First    20.77  1248.0    7.0   6.00
# 4    Diesel    Automatic     Second    15.20  1968.0    5.0  17.74

# %%
sns.heatmap(final_dataset.isnull(),yticklabels=False,cmap="viridis")

# %%
final_dataset.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Seats                  53
# Price                1234
# dtype: int64

# %%
np.mean(final_dataset['Seats'])
# Out:
# 5.279722222222222

# %%
final_dataset['Seats']=final_dataset['Seats'].fillna(5)

# %%
final_dataset.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Seats                   0
# Price                1234
# dtype: int64

# %%
np.mean(final_dataset['Price'])
# Out:
# 9.479468350224273

# %%
final_dataset['Price']=final_dataset['Price'].fillna(9.47)

# %%
sns.heatmap(final_dataset.isnull())

# %%
final_dataset.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine  Seats  Price
# 0       CNG       Manual      First    26.60   998.0    5.0   1.75
# 1    Diesel       Manual      First    19.67  1582.0    5.0  12.50
# 2    Petrol       Manual      First    18.20  1199.0    5.0   4.50
# 3    Diesel       Manual      First    20.77  1248.0    7.0   6.00
# 4    Diesel    Automatic     Second    15.20  1968.0    5.0  17.74

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
final_dataset['Name']=le.fit_transform(final_dataset['Name'])
final_dataset['Location']=le.fit_transform(final_dataset['Location'])
final_dataset['Fuel_Type']=le.fit_transform(final_dataset['Fuel_Type'])
final_dataset['Transmission']=le.fit_transform(final_dataset['Transmission'])
final_dataset['Owner_Type']=le.fit_transform(final_dataset['Owner_Type'])

# %%
final_dataset
# Out:
#       Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0     1310         9  2010              72000          0             1
# 1      560        10  2015              41000          1             1
# 2      529         2  2011              46000          4             1
# 3     1160         2  2012              87000          1             1
# 4       23         3  2013              40670          1             0
# ...    ...       ...   ...                ...        ...           ...
# 1229  2013         5  2011              89411          1             1
# 1230  1988         9  2015              59000          4             0
# 1231  1499         8  2012              28000          1             1
# 1232  1988        10  2013              52262          4             0
# 1233  1366         7  2014              72443          1             0
#
#       Owner_Type  Mileage  Engine  Seats  Price
# 0              0    26.60   998.0    5.0   1.75
# ...

# %%
final_dataset.dtypes
# Out:
# Name                   int32
# Location               int32
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int32
# Transmission           int32
# Owner_Type             int32
# Mileage              float64
# Engine               float64
# Seats                float64
# Price                float64
# dtype: object

# %% [markdown]
# Feature Selection

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
x=final_dataset.iloc[: ,0:-1]
y=final_dataset.iloc[: ,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
model=SelectFromModel(Lasso(alpha=0.001,random_state=0))
model.fit(x_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.001, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
model.get_support()
# Out:
# array([ True,  True,  True, False,  True,  True,  True,  True,  True,
#         True])

# %%
x_train.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Seats'],
#       dtype='object')

# %%
x_train=x_train.drop(['Kilometers_Driven'],axis=1)

# %%
x_test=x_test.drop(['Kilometers_Driven'],axis=1)

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()
le.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("R2 score using train data: ",le.score(x_train,y_train))
# Out:
# R2 score using train data:  0.5501834737399052

# %%
print("R2 score using test data: ",le.score(x_test,y_test))
# Out:
# R2 score using test data:  0.538923663151656

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 50, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.2s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.2s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.4s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# ...

# %%
predict=rf_random.predict(x_test)

# %%
sns.distplot(y_test - predict)

# %%
from sklearn import metrics
print("MSE",metrics.mean_squared_error(y_test,predict))
# Out:
# MSE 26.634884609639933

# %%
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,predict)))
# Out:
# RMSE 5.1608995930593276

# %%
print("MAE",metrics.mean_absolute_error(y_test,predict))
# Out:
# MAE 2.6724184149919297

# %%
import pickle

# %%
file=open("rf_regressor.pkl","wb")
pickle.dump(rf_random,file)
